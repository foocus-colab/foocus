# %%
# !pip install -q pygit2==1.15.1
import os

# =============================
# CLONAR FOOOCUS (SE NÃO EXISTIR)
# =============================
if not os.path.exists('/content/Fooocus'):
    # %cd /content
    # !git clone https://github.com/lllyasviel/Fooocus.git

# %cd /content/Fooocus

# =============================
# BAIXAR MODELO SDXL (YAMER'S REALISTIC 5)
# =============================
MODEL_PATH = '/content/Fooocus/models/checkpoints/yamers_realistic_5.safetensors'

if not os.path.exists(MODEL_PATH):
    # %cd /content/Fooocus/models/checkpoints
    # !wget -O yamers_realistic_5.safetensors "https://civitai.com/api/download/models/299716?type=Model&format=SafeTensor&size=full&fp=fp16"

# %cd /content/Fooocus

# =============================
# INICIAR FOOOCUS
# =============================
# !python entry_with_update.py --share --always-low-vram --disable-analytics
