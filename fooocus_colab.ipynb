# %%
# ==============================================
# 1️⃣ Garantir que GPU está ativa
# ==============================================
# !nvidia-smi

# ==============================================
# 2️⃣ Instalar PyTorch com CUDA 12
# ==============================================
# !pip uninstall -y torch torchvision torchaudio cupy cupy-cuda12x cupy-cuda11x pymatting rembg
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# ==============================================
# 3️⃣ Instalar dependências mínimas
# ==============================================
# !pip install pygit2==1.15.1 packaging

# ==============================================
# 4️⃣ Clonar Fooocus limpo
# ==============================================
# %cd /content
# !rm -rf Fooocus
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus

# ==============================================
# 5️⃣ Remover módulo que puxa cupy
# ==============================================
# !sed -i "/inpaint_mask/d" modules/async_worker.py

# ==============================================
# 6️⃣ Rodar Fooocus
# ==============================================
# !python entry_with_update.py --share --always-high-vram
