# %% [markdown]
# # 🚀 Fooocus Colab (Versão Blindada 2026)
# Este notebook corrige automaticamente problemas com NumPy, CuPy e Torch no Colab.
# Execute as células na ordem.

# %%
# ===== FIX DEFINITIVO COLAB 2026 =====

# !pip uninstall -y cupy cupy-cuda12x numpy torch torchvision torchaudio -q

# Torch compatível com CUDA 12
# !pip install torch==2.2.2+cu121 torchvision==0.17.2+cu121 torchaudio==2.2.2+cu121 --index-url https://download.pytorch.org/whl/cu121 -q

# Fix NumPy
# !pip install numpy==1.26.4 -q

# CuPy correto
# !pip install cupy-cuda12x==12.3.0 -q

# Reiniciar runtime automaticamente
import os
os.kill(os.getpid(), 9)

# %%
# Clonar Fooocus
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus

# %%
# Rodar Fooocus
# !python entry_with_update.py --share --always-high-vram
