# %% [markdown]
# # 🚀 Fooocus Colab (Versão Blindada 2026)
# Este notebook corrige automaticamente problemas com NumPy, CuPy e Torch no Colab.
# Execute as células na ordem.

# %%
# ===== FIX DEFINITIVO COLAB 2026 =====

print("🔄 Limpando ambiente...")

# !pip uninstall -y torch torchvision torchaudio cupy-cuda12x -q

print("📦 Instalando PyTorch CUDA 12.1...")

# !pip install torch==2.2.2+cu121 \
torchvision==0.17.2+cu121 \
torchaudio==2.2.2+cu121 \
--index-url https://download.pytorch.org/whl/cu121 -q

print("📦 Instalando CuPy compatível com RAPIDS 26.x...")

# !pip install cupy-cuda12x==13.6.0 -q

print("♻️ Reiniciando runtime automaticamente...")

import os
os.kill(os.getpid(), 9)

# %%
# Clonar Fooocus
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus

# %%
# Rodar Fooocus
# !python entry_with_update.py --share --always-high-vram
