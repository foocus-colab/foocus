# %%
# ===== 1️⃣ Instalar dependências mínimas =====
# !pip install pygit2==1.15.1 packaging

# ===== 2️⃣ Ir para /content =====
# %cd /content

# ===== 3️⃣ Remover versão antiga (se existir) =====
# !rm -rf Fooocus

# ===== 4️⃣ Clonar repositório =====
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus

# ===== 5️⃣ Rodar Fooocus =====
# !python entry_with_update.py --share --always-high-vram
