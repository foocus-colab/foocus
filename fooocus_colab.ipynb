# %%
import torch, os

print('CUDA:', torch.cuda.is_available())
if not torch.cuda.is_available():
    raise RuntimeError('❌ GPU NAO ESTA ATIVA. Va em Ambiente de execucao -> Alterar tipo -> GPU e reinicie a sessao.')

print('GPU:', torch.cuda.get_device_name(0))

# !pip install -q pygit2==1.15.1

if not os.path.exists('/content/Fooocus'):
    # %cd /content
    # !git clone https://github.com/lllyasviel/Fooocus.git

# %cd /content/Fooocus
# !python entry_with_update.py --share --always-low-vram --disable-analytics
